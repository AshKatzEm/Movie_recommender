# %% [markdown]
# <a href="https://colab.research.google.com/github/AshKatzEm/Movie_recommender/blob/main/Movie_explorer1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
RatingsMerge = pd.read_csv('/content/drive/MyDrive/Movie_recommender/Data/RatingsMerge.csv')
#/content/drive/MyDrive/Movie_recommender/Data/MovieMerge.csv

# %%
RatingsMerge
# Out:
#         userId  movieId  rating  timestamp_x       tag  timestamp_y  \
# 0           14      110     4.5   1442169623      epic   1443148538
# 1         3086      110     5.0   1462977009      epic   1463675332
# 2         5848      110     4.0   1432234167      epic   1432234174
# 3        25286      110     2.5   1412107998      epic   1455671055
# 4        28905      110     4.0   1487342800      epic   1487342816
# ...        ...      ...     ...          ...       ...          ...
# 413664  253839   116849     0.5   1416258848   boring!   1423926073
# 413665  209212   141761     2.5   1454635288  handycam   1454637536
# 413666  212343   141761     2.5   1442011337  handycam   1442006411
# 413667  282552   117549     5.0   1421626677  handycam   1421626923
# 413668   77520    27369     3.5   1252900736       mtv   1252900721
#
#                                      title                  genres  tagId
# 0                        Braveheart (1995)        Action|Drama|War    359
# ...

# %%
RatingsMerge[RatingsMerge.isnull().values]
# Out:
# Empty DataFrame
# Columns: [userId, movieId, rating, timestamp_x, tag, timestamp_y, title, genres, tagId]
# Index: []

# %% [markdown]
# Looks like our data is pretty clean. Let's see if we can find some ubiquity. In the big picture, we're trying to provide a recommendation to a user based on some interest. Let's say the user is a "userId". More specifically, we want to find a "userId" that fits with our users interests and then we can provide other content that our user might like based on what this "userId" also likes.

# %%
#(RatingsMerge.where(RatingsMerge.userId == 14) == RatingsMerge.mask(~RatingsMerge.userId == 14))
RatingsMerge[(RatingsMerge['userId'] == 14) & (RatingsMerge['rating'] == 4.5)]
# Out:
#        userId  movieId  rating  timestamp_x           tag  timestamp_y  \
# 0          14      110     4.5   1442169623          epic   1443148538
# 26569      14      318     4.5   1442169454  imdb top 250   1442615195
# 44772      14      318     4.5   1442169454       justice   1442615192
#
#                                   title            genres  tagId
# 0                     Braveheart (1995)  Action|Drama|War    359
# 26569  Shawshank Redemption, The (1994)       Crime|Drama    536
# 44772  Shawshank Redemption, The (1994)       Crime|Drama    585
